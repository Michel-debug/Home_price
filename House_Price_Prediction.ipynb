# %% [markdown]
# # **Analysis of House Price Prediction using Lasso & Ridge Regression models**

# %% [markdown]
# This document outlines the analysis of a dataset concerning house pricing with the aim to implement Ridge and Lasso regression models. These models are chosen for their effectiveness in handling multicollinearity and providing regularized solutions, making them suitable for real estate market analysis.
#
# 1. Dataset Description
#
# The dataset comprises 81 various features detailed as follows:
#
# - $\textbf{Identification (Id)}:$ A unique identifier for each property.
# - $\textbf{Building Class (MSSubClass)}:$ The type of dwelling involved in the sale.
# - $\textbf{Zoning Classification (MSZoning)}:$ The general zoning classification of the sale.
# - $\textbf{Linear Feet of Street Connected to Property (LotFrontage)}:$
# - $\textbf{Lot Size in Square Feet (LotArea)}:$
# - $\textbf{Type of Road Access (Street)}:$
# - $\textbf{Type of Alley Access (Alley)}:$
# - $\textbf{General Shape of Property (LotShape)}:$
# - $\textbf{Flatness of the Property (LandContour)}:$
# - $\textbf{Type of Utilities Available (Utilities)}:$
# - $\textbf{Lot Configuration (LotConfig)}:$
# - $\textbf{Slope of Property (LandSlope)}:$
# - $\textbf{Physical Locations within Ames City Limits (Neighborhood)}:$
# - $\textbf{Proximity to Main Road or Railroad (Condition1, Condition2)}:$
# - $\textbf{Type of Dwelling (BldgType)}:$
# - $\textbf{Style of Dwelling (HouseStyle)}:$
# - $\textbf{Rates the Overall Material and Finish of the House (OverallQual)}:$
# - $\textbf{Rates the Overall Condition of the House (OverallCond)}:$
# - $\textbf{Original Construction Date (YearBuilt)}:$
# - $\textbf{Remodel Date (YearRemodAdd)}:$
# - $\textbf{Roof Type (RoofStyle)}:$
# - $\textbf{Roof Material (RoofMatl)}:$
# - $\textbf{Exterior Covering on House (Exterior1st, Exterior2nd)}:$
# - $\textbf{Masonry Veneer Type (MasVnrType)}:$
# - $\textbf{Masonry Veneer Area in Square Feet (MasVnrArea)}:$
# - $\textbf{Evaluates the Quality of the Material on the Exterior (ExterQual)}:$
# - $\textbf{Evaluates the Present Condition of the Material on the Exterior (ExterCond)}:$
# - $\textbf{Type of Foundation (Foundation)}:$
# - $\textbf{Height of the Basement (BsmtQual)}:$
# - $\textbf{General Condition of the Basement (BsmtCond)}:$
# - $\textbf{Walkout or Garden Level Basement Walls (BsmtExposure)}:$
# - $\textbf{Basement Finished Area (BsmtFinSF1, BsmtFinSF2)}:$
# - $\textbf{Unfinished Square Feet of Basement Area (BsmtUnfSF)}:$
# - $\textbf{Total Square Feet of Basement Area (TotalBsmtSF)}:$
# - $\textbf{Type of Heating (Heating)}:$
# - $\textbf{Heating Quality and Condition (HeatingQC)}:$
# - $\textbf{Central Air Conditioning (CentralAir)}:$
# - $\textbf{Electrical System (Electrical)}:$
# - $\textbf{First Floor Square Feet (1stFlrSF)}:$
# - $\textbf{Second Floor Square Feet (2ndFlrSF)}:$
# - $\textbf{Low Quality Finished Square Feet (LowQualFinSF)}:$
# - $\textbf{Above Grade (Ground) Living Area Square Feet (GrLivArea)}:$
# - $\textbf{Basement Full Bathrooms (BsmtFullBath)}:$
# - $\textbf{Basement Half Bathrooms (BsmtHalfBath)}:$
# - $\textbf{Full Bathrooms Above Grade (FullBath)}:$
# - $\textbf{Half Baths Above Grade (HalfBath)}:$
# - $\textbf{Bedrooms Above Grade (BedroomAbvGr)}:$
# - $\textbf{Kitchens Above Grade (KitchenAbvGr)}:$
# - $\textbf{Kitchen Quality (KitchenQual)}:$
# - $\textbf{Total Rooms Above Grade (Excluding Bathrooms) (TotRmsAbvGrd)}:$
# - $\textbf{Home Functionality (Functional)}:$
# - $\textbf{Number of Fireplaces (Fireplaces) and Fireplace Quality (FireplaceQu)}:$
# - $\textbf{Garage Location (GarageType)}:$
# - $\textbf{Year Garage was Built (GarageYrBlt)}:$
# - $\textbf{Interior Finish of the Garage (GarageFinish)}:$
# - $\textbf{Size of Garage in Car Capacity (GarageCars)}:$
# - $\textbf{Size of Garage in Square Feet (GarageArea)}:$
# - $\textbf{Garage Quality (GarageQual)}:$
# - $\textbf{Garage Condition (GarageCond)}:$
# - $\textbf{Paved Driveway (PavedDrive)}:$
# - $\textbf{Wood Deck Area in Square Feet (WoodDeckSF)}:$
# - $\textbf{Open Porch Area in Square Feet (OpenPorchSF)}:$
# - $\textbf{Enclosed Porch Area in Square Feet (EnclosedPorch)}:$
# - $\textbf{Three Season Porch Area in Square Feet (3SsnPorch)}:$
# - $\textbf{Screen Porch Area in Square Feet (ScreenPorch)}:$
# - $\textbf{Pool Area in Square Feet (PoolArea) and Pool Quality (PoolQC)}:$
# - $\textbf{Fence Quality (Fence)}:$
# - $\textbf{Miscellaneous Feature not covered in other categories (MiscFeature)}:$
# - $\textbf{Value of Miscellaneous Feature (MiscVal)}:$
# - $\textbf{Month Sold (MoSold)}:$
# - $\textbf{Year Sold (YrSold)}:$
# - $\textbf{Type of Sale (SaleType)}:$
# - $\textbf{Condition of Sale (SaleCondition)}:$
# - $\textbf{Sale Price (SalePrice)}:$ The property's sale price in dollars:
#
# This last feature is the target variable that we will try to predict.
#
#
# 2. Methodology
# Ridge and Lasso regression models will be applied to predict house prices. These models are particularly adept at dealing with multicollinearity in the data, a common issue in real estate datasets. The regularization in Ridge and Lasso helps to enhance the model's accuracy and avoid overfitting.
#
# 3. Conclusions
# The analysis will provide valuable insights into the real estate market and demonstrate the efficacy of advanced regression models in predicting house prices.

# %%
# We import the libraries we will be using

import seaborn as sns
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from matplotlib import style
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# %matplotlib inline

# %%
# Reading the CSV file
# We consider 2 datasets: df_1980_2023 and df_2000_2023

df_housing = pd.read_csv('train.csv')
df_housing.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# Calculando la mediana o el promedio de precio para cada número de habitaciones
price_by_rooms = df_housing.groupby('TotRmsAbvGrd')['SalePrice'].mean().reset_index()
#print(price_by_rooms)
# Creando un gráfico de barras
plt.figure(figsize=(15, 9))
plt.bar(price_by_rooms['TotRmsAbvGrd'], price_by_rooms['SalePrice'], color='skyblue', edgecolor='black')

# Establecer el título y las etiquetas
plt.title('Mean House Price by Number of Rooms')
plt.xlabel('Number of Rooms')
plt.ylabel('Average Price')
plt.xticks(price_by_rooms['TotRmsAbvGrd'])  # Asegurándose de que hay un tick para cada número de habitaciones

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Cleaning Part

# %%
df_housing.describe().T

all_data_na = (df_housing.isnull().sum() / len(df_housing)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation=90)
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
plt.show()

# %% [markdown]
# ## Imputing Missing Values
#
# $\textbf{PoolQC : data description says NA means "No Pool"} $
#
# $\textbf{MiscFeature : data description says NA means "no misc feature"}$
#
# $\textbf{Alley : data description says NA means "no alley access"}$
#
# $\textbf{Fence : data description says NA means "no fence"}$
#
# $\textbf{FireplaceQu : data description says NA means "no fireplace"}$
#
# $\textbf{LotFrontage : Since the area of each street connected to the house property most likely have a similar area to other houses in its neighborhood , we can fill in missing values by the median LotFrontage of the neighborhood.}$
#
# $\textbf{GarageType, GarageFinish, GarageQual and GarageCond : Replacing missing data with "None".}$
#
# $\textbf{GarageYrBlt, GarageArea and GarageCars : Replacing missing data with 0.}$
#
# $\textbf{BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, BsmtFullBath and BsmtHalfBath: Replacing missing data with 0.}$
#
# $\textbf{BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1 and BsmtFinType2 : For all these categorical basement-related features, NaN means that there isn't a basement.}$
#
# $\textbf{MasVnrArea and MasVnrType : NA most likely means no masonry veneer for these houses. We can fill 0 for the area and None for the type.}$
#
# $\textbf{MSZoning (The general zoning classification) : 'RL' is by far the most common value. So we can fill in missing values with 'RL'.}$
#
# $\textbf{Utilities : For this categorical feature all records are "AllPub", except for one "NoSeWa" and 2 NA . Since the house with 'NoSewa' is in the training set, this feature won't help in predictive modelling. We can then safely remove it.}$
#
# $\textbf{Functional : data description says NA means typical.}$
#
# $\textbf{Electrical : It has one NA value. Since this feature has mostly 'SBrkr', we can set that for the missing value.}$
#
# $\textbf{KitchenQual: Only one NA value, and same as Electrical, we set 'TA' (which is the most frequent) for the missing value in KitchenQual.}$
# $\textbf{Exterior1st and Exterior2nd : Both Exterior 1 & 2 have only one missing value. We will just substitute in the most common string }$
# $\textbf{SaleType : Fill in again with most frequent which is "WD" }$
#
# $\textbf{MSSubClass : Na most likely means No building class. We can replace missing values with None }$

# %% [markdown]
# # Data Analysis

# %% [markdown]
# To calculate the correlation between two variables, we will use a statistical measure called the correlation coefficient. The most common correlation coefficient used is the Pearson correlation coefficient (also known as Pearson's Correlation Coefficient - PCC).
#
# In the following, we define how to calculate the Pearson correlation coefficient between 2 variables/features X and Y:
#
# 1. Calculate the means: Calculate the mean of both X and Y values, denoted as $\bar{X}$ and $\bar{Y}$.
#
# 2. Calculate the covariance: Compute the covariance between X and Y values. The formula for covariance is:
#
# $$ Cov(X, Y) = \sum_{i=1}^{n} \frac{(X_{i} - \bar{X}) \cdot (Y_{i} - \bar{Y})}{n - 1} $$
#
# Where:
# $$ \text{Cov(X, Y) is the covariance between X and Y} $$
# $$ X_{i} \text{ and } Y_{i} \text{ are individual data points of X and Y} $$
# $$ \bar{X} \text{ is the mean of X} $$
# $$ \bar{Y} \text{ is the mean of Y} $$
# $$ n \text{ is the number of data points} $$
#
# 4. Calculate the standard deviations: Compute the standard deviation of both X and Y. The formula for standard deviation is:
#
# $$ SD(X) = \sqrt{\sum_{i=1}^{n} \frac{(X_{i} - \bar{X})^2}{n - 1}} $$
# $$ SD(Y) = \sqrt{\sum_{i=1}^{n} \frac{(Y_{i} - \bar{Y})^2}{n - 1}} $$
#
# Where:
# $$ \text{SD(X) is the standard deviation of height} $$
# $$ \text{SD(Y) is the standard deviation of weight} $$
# $$ X_{i} \text{ and } Y_{i} \text{ are individual data points of height and weight} $$
# $$ \bar{X} \text{ is the mean of height} $$
# $$ \bar{Y} \text{ is the mean of weight} $$
# $$ n \text{ is the number of data points} $$
#
# 5. Calculate the Pearson Correlation Coefficient:
#
# Finally, we can calculate the Pearson Correlation Coefficient using the following formula:
#
# $$ r = \frac{Cov(X, Y)}{SD(X) \cdot SD(Y)} $$
#
# 6. Interpretation of values:
#
# The resulting value of r will be between -1 and 1.
# - If r is close to 1, it indicates a strong positive linear correlation (as one variable increases, the other tends to increase).
# - If r is close to -1, it indicates a strong negative linear correlation (as one variable increases, the other tends to decrease and viceversa).
# - If r is close to 0, it suggests a weak or no linear correlation between the two variables.

# %%
df_housing = df_housing.select_dtypes(include = ['float64', 'int64'])

housing_correlation_matrix = df_housing.corr()

# Plot the heatmap
plt.figure(figsize=(30,25))
sns.heatmap(housing_correlation_matrix, vmax=0.8, annot=True, fmt=".2f", cmap='coolwarm')

# Show the plot
plt.show()

# %%
# We create a DataFrame from the correlation matrix, stack it, and reset the index
corr_pairs = housing_correlation_matrix.unstack().reset_index()

# Now, we can access to the pairs via order (numbers), before we had to write to access with column titles
#print(corr_pairs)
#print(corr_pairs[[0,0]])

# We rename the columns where the variables names are stored to simplify
corr_pairs.columns = ['Variable1', 'Variable2', 'Correlation']


# Remove self correlation (obviously the variable is correlated with itself)
corr_pairs = corr_pairs[corr_pairs['Variable1'] != corr_pairs['Variable2']]
#print(corr_pairs)

# We add a new column with the absolute correlation value (it will be easier to compare this way)
corr_pairs['AbsCorrelation'] = corr_pairs['Correlation'].abs()

# Sort by absolute value of correlation in descending order
sorted_pairs = corr_pairs.sort_values('AbsCorrelation', ascending=False)
#print(sorted_pairs)


# We drop duplicates
no_duplicates = sorted_pairs.drop_duplicates(subset=['AbsCorrelation'])


# Take the top 4 unique pairs
top_pairs = no_duplicates
top_pairs
# Out:
#          Variable1    Variable2  Correlation  AbsCorrelation
# 1052    GarageArea   GarageCars     0.882475        0.882475
# 956    GarageYrBlt    YearBuilt     0.825667        0.825667
# 890   TotRmsAbvGrd    GrLivArea     0.825489        0.825489
# 506       1stFlrSF  TotalBsmtSF     0.819530        0.819530
# 1410     SalePrice  OverallQual     0.790982        0.790982
# ...            ...          ...          ...             ...
# 1102   OpenPorchSF           Id    -0.000477        0.000477
# 1212     3SsnPorch      MiscVal     0.000354        0.000354
# 696   BsmtHalfBath  TotalBsmtSF    -0.000315        0.000315
# 677   BsmtFullBath    3SsnPorch    -0.000106        0.000106
# 950    GarageYrBlt           Id     0.000072        0.000072
#
# [703 rows x 4 columns]

# %%
df_housing = df_housing.dropna()

#saleprice correlation matrix
k = 15 #number of variables for heatmap
plt.figure(figsize=(20,12))
cols = housing_correlation_matrix.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(df_housing[cols].values.T)
#sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# Top variable correlated

# %%
#scatterplot
#sns.set()
#cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
#sns.pairplot(df_housing[cols], size = 2.5)
#plt.show()

# %%
# 创建图表
fig, ax = plt.subplots(2, 2, figsize=(15, 10))
df_housing = df_housing[["SalePrice", "OverallQual", "GrLivArea", "TotRmsAbvGrd", "GarageCars", "GarageArea", "FullBath", "1stFlrSF", "TotalBsmtSF", "YearBuilt", "MasVnrArea", "Fireplaces", "YearRemodAdd", "LotArea", "BsmtFinSF1"]]
print(df_housing["GrLivArea"])
# 原始数据的散点图
ax[0, 0].scatter((df_housing["GrLivArea"]), df_housing["SalePrice"])
ax[0, 0].set_title("Original Data")
ax[0, 0].set_xlabel("GrLivArea")
ax[0, 0].set_ylabel("SalePrice")
# 原始数据的直方图
ax[1, 0].hist(df_housing["GrLivArea"], bins=30)
ax[1, 0].set_title("Original GrLivArea Distribution")
ax[1, 0].set_xlabel("GrLivArea")
ax[1, 0].set_ylabel("Frequency")
df_housing["GrLivArea"] = np.log(df_housing["GrLivArea"])


Y_data_nparray = np.array(df_housing["SalePrice"])
Y_data_nparray = np.log(Y_data_nparray)
print("Complete Y Data:\n\n", Y_data_nparray, "\n")

X_data_nparray = np.array(df_housing.drop("SalePrice", axis =1))
print("Complete X Data:\n\n", X_data_nparray, "\n")



# 对数转换后的散点图
ax[0, 1].scatter(df_housing["GrLivArea"], Y_data_nparray)
ax[0, 1].set_title("Log Transformed Data")
ax[0, 1].set_xlabel("Log(GrLivArea)")
ax[0, 1].set_ylabel("Log(SalePrice)")


# 对数转换后的直方图
ax[1, 1].hist(df_housing["GrLivArea"], bins=30)
ax[1, 1].set_title("Log Transformed GrLivArea Distribution")
ax[1, 1].set_xlabel("Log(GrLivArea)")
ax[1, 1].set_ylabel("Frequency")

plt.tight_layout()
plt.show()
# Out:
# 0       1710
# 1       1262
# 2       1786
# 3       1717
# 4       2198
#         ...
# 1455    1647
# 1456    2073
# 1457    2340
# 1458    1078
# 1459    1256
# Name: GrLivArea, Length: 1121, dtype: int64
# Complete Y Data:
#
#  [12.24769432 12.10901093 12.31716669 ... 12.49312952 11.86446223
#  11.90158345]
#
# Complete X Data:
#
#  [[7.00000000e+00 7.44424865e+00 8.00000000e+00 ... 2.00300000e+03
#   8.45000000e+03 7.06000000e+02]
#  [6.00000000e+00 7.14045304e+00 6.00000000e+00 ... 1.97600000e+03
#   9.60000000e+03 9.78000000e+02]
#  [7.00000000e+00 7.48773376e+00 6.00000000e+00 ... 2.00200000e+03
#   1.12500000e+04 4.86000000e+02]
#  ...
#  [7.00000000e+00 7.75790621e+00 9.00000000e+00 ... 2.00600000e+03
#   9.04200000e+03 2.75000000e+02]
#  [5.00000000e+00 6.98286275e+00 5.00000000e+00 ... 1.99600000e+03
#   9.71700000e+03 4.90000000e+01]
#  [5.00000000e+00 7.13568735e+00 6.00000000e+00 ... 1.96500000e+03
#   9.93700000e+03 8.30000000e+02]]

# %% [markdown]
# # Training & Test Split

# %%
# Splitting the previous complete Data into Training Data & Testing Data into 80% for Training & 20% for Testing

X_train, X_test, Y_train, Y_test = train_test_split(X_data_nparray, Y_data_nparray, test_size=0.2)
print("X_Train Data Shape:", X_train.shape, "\n")
print("Y_Train Data Shape:", Y_train.shape, "\n")
print("X_Test Data Shape:", X_test.shape, "\n")
print("Y_Test Data Shape:", Y_test.shape, "\n")
# Out:
# X_Train Data Shape: (896, 14)
#
# Y_Train Data Shape: (896,)
#
# X_Test Data Shape: (225, 14)
#
# Y_Test Data Shape: (225,)

# %% [markdown]
# ## 1. Linear Regression
# Building First model of regression - Linear Regression

# %%
# Create a pipeline that first standardizes the data then applies Linear regression
# StandardScaler will normalize the features (subtract mean and divide by standard-deviation)
pipeline_linear = Pipeline([
    ('scaler', StandardScaler()),
    ('linear', LinearRegression())
])

param_grid = {}

# Initialize GridSearchCV
grid_linear = GridSearchCV(pipeline_linear, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the model on the training data
grid_linear.fit(X_train, Y_train)

# The best model from grid search
best_linear_model = grid_linear.best_estimator_

# %% [markdown]
# In order to evaluate the model's prediction, we will consider 2 main metrics.
#
# $\underline{\text{Definition of the metrics}}$:
#
# 1. RMSE (Root Mean Square Error)
#
# $$ RMSE ={\sqrt {{\frac{1}{n}}\sum _{i=1}^{n}(X_{i}-\hat{X_{i}})^{2}}} $$
#
# where
# $n$ is the number of observations, $X_{i}$ is the actual observed value and $\hat{X_{i}}$ is the predicted value from the model.
#
# $\underline{Interpretation}:$
#
# - An RMSE of 0 indicates that the model makes perfect predictions with no errors, which is typically not possible with real-world data.
#
# - The RMSE is always non-negative, and a lower value indicates a better fit. The closer the RMSE is to 0, the better the model is at predicting the observed outcomes.
#
# 2. R2-Score
#
# $$ R^2 = 1 - \frac{SS_{res}}{SS_{tot}} = 1 - \frac{\sum_{i=1}^{n} (X_i - \hat{X}_i)^2}{\sum_{i=1}^{n} (X_{i} - \bar{X})^2}$$
#
# The terms $SS_{res}$(Sum of Squares of Residuals) and $ SS_{tot}$(Total Sum of Squarees) are defined as follows:
#
# $$ SS_{res} = \sum_{i=1}^{n} (X_i - \hat{X}_i)^2 $$
#
# $$ SS_{tot} = \sum_{i=1}^{n} (X_{i} - \bar{X})^2 $$
#
# Where $\bar{X}$ denotes the mean of X.
#
# $\underline{Interpretation}:$
#
# - An R² score of 1 indicates that the regression predictions perfectly fit the data.
# - An R² score of 0 indicates that the model explains none of the variability of the response data around its mean.
# - Negative values of R² may occur when the model fits the data worse than a horizontal hyperplane at the mean of the dependent variable.

# %%
# Define the Real & Prediction Values

Y_prediction_linear = best_linear_model.predict(X_test)

# Evaluate the model with the chosen metrics
RMSE_score_linear = np.sqrt(mean_squared_error(Y_test, Y_prediction_linear))
R2_score_linear = r2_score(Y_test, Y_prediction_linear)

print(RMSE_score_linear, R2_score_linear)
# Out:
# 0.13368457693112287 0.8853335047565598

# %% [markdown]
# ## 2. Polynomial Regression
# Building Second model of regression - Polynomial Regression

# %%
X_train_polynomial, X_test_polynomial, Y_train_polynomial, Y_test_polynomial = train_test_split(X_data_nparray, Y_data_nparray, test_size=0.2)

# %%
# Create a pipeline that first standardizes the data, applies PolynomialFeatures, and then applies Linear Regression
# StandardScaler will normalize the features (subtract mean and divide by standard-deviation)
# PolynomialFeatures will create polynomial features up to the specified degree
# Linear Regression will perform regression on the polynomial features
pipeline_poly = Pipeline([
    ('scaler', StandardScaler()),
    ('poly', PolynomialFeatures()),
    ('linear', LinearRegression())
])

# Parameters for GridSearchCV
# Here, we are trying different polynomial degrees for Polynomial regression (if needed)
param_grid = {
    'poly__degree': [2, 3, 4],
}

# Initialize GridSearchCV
grid_polynomial = GridSearchCV(pipeline_poly, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the model on the training data
grid_polynomial.fit(X_train_polynomial, Y_train_polynomial)

# The best model from grid search
best_polynomial_model = grid_polynomial.best_estimator_

# Print the best model parameters
print(f'Best parameters for Polynomial Regression: {grid_polynomial.best_params_}')
# Out:
# Best parameters for Polynomial Regression: {'poly__degree': 2}

# %%
# Define the Real & Prediction Values

Y_prediction_polynomial = best_polynomial_model.predict(X_test_polynomial)

# Evaluate the model with the chosen metrics
RMSE_score_polynomial = np.sqrt(mean_squared_error(Y_test_polynomial, Y_prediction_polynomial))
R2_score_polynomial = r2_score(Y_test_polynomial, Y_prediction_polynomial)

print(RMSE_score_polynomial, R2_score_polynomial)
# Out:
# 0.17588223277504791 0.8004790398073534

# %% [markdown]
# ## 3. Ridge Regression
# Building Third model of regression - Ridge Regression

# %%
# Create a pipeline that first standardizes the data then applies Ridge regression
# StandardScaler will normalize the features (subtract mean and divide by standard-deviation)
pipeline_ridge = Pipeline([
    ('scaler', StandardScaler()),
    ('ridge', Ridge())
])

# Parameters for GridSearchCV
# Here, we are trying different alpha values for Ridge regression
# Alpha is the regularization strength
param_grid = {'ridge__alpha': np.logspace(-4, 4, 20)}

# Initialize GridSearchCV
grid_ridge = GridSearchCV(pipeline_ridge, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the model on the training data
grid_ridge.fit(X_train, Y_train)

# The best model from grid search
best_ridge_model = grid_ridge.best_estimator_

# Best alpha parameter found
best_ridge_alpha = grid_ridge.best_params_['ridge__alpha']

# Print the best alpha parameter
print(f'Best alpha parameter for Ridge Regression: {best_ridge_alpha}')
# Out:
# Best alpha parameter for Ridge Regression: 78.47599703514607

# %% [markdown]
# 3.1 Standardization + Training

# %%
# Define the Real & Prediction Values

Y_prediction_ridge = best_ridge_model.predict(X_test)

# Evaluate the model with the chosen metrics
RMSE_score_ridge = np.sqrt(mean_squared_error(Y_test, Y_prediction_ridge))
R2_score_ridge = r2_score(Y_test, Y_prediction_ridge)

print(RMSE_score_ridge, R2_score_ridge)
# Out:
# 0.13699217873021854 0.8795891915916909

# %% [markdown]
# ## 4. Lasso Regression

# %%
# We create a pipeline that first standardizes the data then applies Lasso regression
# StandardScaler will normalize the features (subtract mean and divide by standard-deviation)
pipeline_lasso = Pipeline([
    ('scaler', StandardScaler()),
    ('lasso', Lasso())
])

# Parameters for GridSearchCV
# Here, we are trying different alpha values for Lasso regression
# Alpha is the regularization strength
param_grid = {'lasso__alpha': np.logspace(-4, 4, 20)}

# Initialize GridSearchCV
grid_lasso = GridSearchCV(pipeline_lasso, param_grid, cv=5, scoring='neg_mean_squared_error')

# Fit the model on the training data
grid_lasso.fit(X_train, Y_train)

# The best model from grid search
best_lasso_model = grid_lasso.best_estimator_

# Best alpha parameter found
best_lasso_alpha = grid_lasso.best_params_['lasso__alpha']

# Print the best alpha parameter
print(f'Best alpha parameter for Lasso Regression: {best_lasso_alpha}')
# Out:
# Best alpha parameter for Lasso Regression: 0.004832930238571752

# %%
# Define the Real & Prediction Values

Y_prediction_lasso = best_lasso_model.predict(X_test)

# Evaluate the model with the chosen metrics
RMSE_score_lasso = np.sqrt(mean_squared_error(Y_test, Y_prediction_lasso))
R2_score_lasso = r2_score(Y_test, Y_prediction_lasso)

print(RMSE_score_lasso, R2_score_lasso)
# Out:
# 0.1347921244457368 0.8834256605977477

# %% [markdown]
# ## 5. Random forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

# define Pipeline
# This code defines a Pipeline object with two steps: first, it uses StandardScaler to standardize the features 
# by removing the mean and scaling to unit variance, and second, it applies a RandomForestRegressor for regression.
pipeline_rf = Pipeline([
    ('scaler', StandardScaler()),
    ('rf', RandomForestRegressor())
])

# Setting Up the Parameter Grid
# This is the parameter grid for the grid search. It specifies the parameters to be tested: n_estimators (the number of trees in the forest), 
# max_features (the number of features to consider when looking for the best split), and max_depth (the maximum depth of the trees).
#
param_grid_rf = {
    'rf__n_estimators': [100, 200],
    'rf__max_features': ['log2', 'sqrt'],
    'rf__max_depth': [10, 20, None]
}

# initialisation GridSearchCV
grid_rf = GridSearchCV(pipeline_rf, param_grid_rf, cv=5, scoring='neg_mean_squared_error')

# train model
grid_rf.fit(X_train, Y_train)

# get a best model
best_rf_model = grid_rf.best_estimator_

# %%
# Define the Real & Prediction Values

Y_prediction_rf = best_rf_model.predict(X_test)

# Evaluate the model with the chosen metrics
RMSE_score_rf = np.sqrt(mean_squared_error(Y_test, Y_prediction_rf))
R2_score_rf = r2_score(Y_test, Y_prediction_rf)

print(RMSE_score_rf, R2_score_rf)
# Out:
# 0.1396461904455803 0.8748784511247563

# %%
feature_names = df_housing.drop('SalePrice', axis=1).columns

# %%
# Get the feature importance of the random forest model
feature_importances = best_rf_model.named_steps['rf'].feature_importances_

# Create a feature importance map
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importances, y=feature_names)
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importances')
plt.show()

# %%
# prepare a list for stock des resultsets
results = []

# loop differents features
for num_features in range(1, len(feature_importances) + 1):
    # Get top features index and get features
    indices = np.argsort(feature_importances)[-num_features:]
    top_features = feature_names[indices]

    # Recreate training and test sets
    X_train_reduced = X_train[:, indices]
    X_test_reduced = X_test[:, indices]

    # Retrain the model
    rf_reduced = RandomForestRegressor(n_estimators=best_rf_model.named_steps['rf'].n_estimators,
                                       max_features=best_rf_model.named_steps['rf'].max_features,
                                       max_depth=best_rf_model.named_steps['rf'].max_depth)
    rf_reduced.fit(X_train_reduced, Y_train)

    # make predictions
    Y_prediction_reduced = rf_reduced.predict(X_test_reduced)

    # Evaluate and compare the performance of new models
    RMSE_score_reduced = np.sqrt(mean_squared_error(Y_test, Y_prediction_reduced))
    R2_score_reduced = r2_score(Y_test, Y_prediction_reduced)

    # Save results to list
    results.append((num_features, RMSE_score_reduced, R2_score_reduced))

# print all the results
for result in results:
    print(f"Number of Features: {result[0]}, RMSE: {result[1]}, R2 Score: {result[2]}")
# Through the results, we found that by selecting the first 13 features, his accuracy will be better
# Out:
# Number of Features: 1, RMSE: 0.19803915807968261, R2 Score: 0.7483620900776093
# Number of Features: 2, RMSE: 0.1899033682278746, R2 Score: 0.7686128366363136
# Number of Features: 3, RMSE: 0.16674631132721796, R2 Score: 0.8216034720928949
# Number of Features: 4, RMSE: 0.15086142835840544, R2 Score: 0.8539739434397722
# Number of Features: 5, RMSE: 0.15040445038399383, R2 Score: 0.8548572656314464
# Number of Features: 6, RMSE: 0.15231674691825237, R2 Score: 0.8511430082340876
# Number of Features: 7, RMSE: 0.1553114971899383, R2 Score: 0.8452320111350604
# Number of Features: 8, RMSE: 0.14997422676148267, R2 Score: 0.855686423601633
# Number of Features: 9, RMSE: 0.14773459215040255, R2 Score: 0.8599644434658007
# Number of Features: 10, RMSE: 0.14328953707595599, R2 Score: 0.8682644812867337
# Number of Features: 11, RMSE: 0.13957567368262458, R2 Score: 0.8750047838069315
# Number of Features: 12, RMSE: 0.1368587251091856, R2 Score: 0.8798236784281025
# ...

# %% [markdown]
# ## 6. SVM Regression

# %%
from sklearn.svm import SVR

# define Pipeline
pipeline_svr = Pipeline([
    ('scaler', StandardScaler()),
    ('svr', SVR())
])

# Setting up the Parameter Grid
param_grid_svr = {
    'svr__C': [0.1, 1, 10],
    'svr__gamma': ['scale', 'auto'],
    'svr__kernel': ['linear', 'rbf']
}

# Init GridSearchCV
grid_svr = GridSearchCV(pipeline_svr, param_grid_svr, cv=5, scoring='neg_mean_squared_error')

# train model
grid_svr.fit(X_train, Y_train)

# get a best model
best_svr_model = grid_svr.best_estimator_

# %%
# Define the Real & Prediction Values

Y_prediction_svr = best_svr_model.predict(X_test)

# Evaluate the model with the chosen metrics
RMSE_score_svr = np.sqrt(mean_squared_error(Y_test, Y_prediction_svr))
R2_score_svr = r2_score(Y_test, Y_prediction_svr)

print(RMSE_score_svr, R2_score_svr)
# Out:
# 0.14935169978102944 0.8568819975432458

# %%
# Best Performance of the Regressor Models
best_score = max(R2_score_linear, R2_score_polynomial, R2_score_ridge, R2_score_lasso,R2_score_rf,R2_score_svr)
index = np.argmax([R2_score_linear, R2_score_polynomial, R2_score_ridge, R2_score_lasso,R2_score_rf,R2_score_svr])
best_regressor = {0:"Linear Regression Model",
                  1:"Polynomial Regression Model",
                  2:"Ridge Model",
                  3:"Lasso Model",
                  4:"Random forest Model",
                  5:"SVM Model"}
print("The Best Performer is {0} with the score of {1}%.".format(best_regressor[index], best_score*100))
# Out:
# The Best Performer is Linear Regression Model with the score of 88.53335047565598%.

# %%
# Create a list of scores and corresponding model names
scores = [R2_score_linear, R2_score_polynomial, R2_score_ridge, R2_score_lasso, R2_score_rf, R2_score_svr]
model_names = ["Linear", "Polynomial", "Ridge", "Lasso", "Random Forest", "SVM"]

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(model_names, scores, color='skyblue')
plt.xlabel('Regression Models')
plt.ylabel('R2 Score')
plt.title('Comparison of Regression Model Performance')
plt.ylim([0, 1])  # Assuming R2 scores are between 0 and 1
# Adding the scores on top of the bars
for i in range(len(scores)):
    plt.text(i, scores[i], f'{scores[i]:.2f}', ha='center', va='bottom')
    #plt.grid()
plt.show()
